# %%
import requests
import re

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}
# 1.获取网页源代码
url = 'https://movie.douban.com/top250'
res = requests.get(url, headers=headers).text

# %%
res
# Out:
# '<!DOCTYPE html>\n<html lang="zh-CN" class="ua-windows ua-webkit">\n<head>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n    <meta name="renderer" content="webkit">\n    <meta name="referrer" content="always">\n    <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />\n    <title>\n豆瓣电影 Top 250\n</title>\n    \n    <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="Expires" content="Sun, 6 Mar 2006 01:00:00 GMT">\n    \n    <link rel="apple-touch-icon" href="https://img1.doubanio.com/cuphead/movie-static/pics/apple-touch-icon.png">\n    <link href="https://img1.doubanio.com/f/vendors/ed9fe787278d57bf9544eb627bb8c5d6d250376b/css/douban.css" rel="stylesheet" type="text/css">\n    <link href="https://img1.doubanio.com/f/vendors/ee6598d46af0bc554cecec9bcbf525b9b0582cb0/css/separation/_all.css" rel="stylesheet" type="text/css">\n   
# ...

# %%
p_title='<span class="title">(.*?)</span>'
re.findall(p_title,res)
# Out:
# ['肖申克的救赎',
#  '&nbsp;/&nbsp;The Shawshank Redemption',
#  '霸王别姬',
#  '泰坦尼克号',
#  '&nbsp;/&nbsp;Titanic',
#  '阿甘正传',
#  '&nbsp;/&nbsp;Forrest Gump',
#  '千与千寻',
#  '&nbsp;/&nbsp;千と千尋の神隠し',
#  '美丽人生',
#  '&nbsp;/&nbsp;La vita è bella',
#  '这个杀手不太冷',
#  '&nbsp;/&nbsp;Léon',
#  '星际穿越',
#  '&nbsp;/&nbsp;Interstellar',
#  '盗梦空间',
#  '&nbsp;/&nbsp;Inception',
#  '楚门的世界',
#  '&nbsp;/&nbsp;The Truman Show',
#  '辛德勒的名单',
#  '&nbsp;/&nbsp;Schindler&#39;s List',
#  '忠犬八公的故事',
#  '&nbsp;/&nbsp;Hachi: A Dog&#39;s Tale',
#  '海上钢琴师',
#  '&nbsp;/&nbsp;La leggenda del pianista sull&#39;oceano',
#  '疯狂动物城',
#  '&nbsp;/&nbsp;Zootopia',
#  '三傻大闹宝莱坞',
#  '&nbsp;/&nbsp;3 Idiots',
#  '放牛班的春天',
#  '&nbsp;/&nbsp;Les choristes',
#  '机器人总动员',
#  '&nbsp;/&nbsp;WALL·E',
#  '无间道',
#  '&nbsp;/&nbsp;無間道',
#  '控方证人',
#  '&nbsp;/&nbsp;Witness for the Prosecution',
#  '大话西游之大圣娶亲',
#  '&nbsp;/&nbsp;西遊記大結局之仙履奇緣',
#  '熔炉',
#  '&nbsp;/&nbsp;도가니',
#  '触不可及',
#  '&nbsp;/&nbsp;Intouchables',
#  '寻梦环游记',
# ...

# %%
p_title='<a href=".*?">\n                            <span class="title">(.*?)</span>'
re.findall(p_title,res)
# Out:
# ['肖申克的救赎',
#  '霸王别姬',
#  '泰坦尼克号',
#  '阿甘正传',
#  '千与千寻',
#  '美丽人生',
#  '这个杀手不太冷',
#  '星际穿越',
#  '盗梦空间',
#  '楚门的世界',
#  '辛德勒的名单',
#  '忠犬八公的故事',
#  '海上钢琴师',
#  '疯狂动物城',
#  '三傻大闹宝莱坞',
#  '放牛班的春天',
#  '机器人总动员',
#  '无间道',
#  '控方证人',
#  '大话西游之大圣娶亲',
#  '熔炉',
#  '触不可及',
#  '寻梦环游记',
#  '教父',
#  '当幸福来敲门']

# %%
title=re.findall(p_title,res)
len(title)
# Out:
# 25

# %%
p_img='<img width="100" alt=".*?" src="(.*?)">'
re.findall(p_img,res)
# Out:
# ['https://img3.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg',
#  'https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg',
#  'https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg',
#  'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg',
#  'https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2557573348.jpg',
#  'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2578474613.jpg',
#  'https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2913554676.jpg',
#  'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2614988097.jpg',
#  'https://img9.doubanio.com/view/photo/s_ratio_poster/public/p513344864.jpg',
#  'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p479682972.jpg',
#  'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p492406163.jpg',
#  'https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2587099240.jpg',
# ...

# %%
img=re.findall(p_img,res)

# %%
len(img)
# Out:
# 25

# %%
img[0]
# Out:
# 'https://img3.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg'

# %%
res1 = requests.get(img[0])
file = open('C:/Users/Administrator/Desktop/pic.jpg', 'wb')  # 注意要以二进制的方式写入
file.write(res1.content)
file.close()

# %%
for i in range(25):
    print(str(i+1)+' '+title[i])
    print(img[i])
    res1 = requests.get(img[i])
    file = open('C:/Users/Administrator/Desktop/movies/'+title[i]+'.jpg', 'wb')  # 注意要以二进制的方式写入
    file.write(res1.content)
    file.close()
# Out:
# 1 肖申克的救赎
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg
# 2 霸王别姬
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg
# 3 泰坦尼克号
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg
# 4 阿甘正传
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg
# 5 千与千寻
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2557573348.jpg
# 6 美丽人生
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2578474613.jpg
# 7 这个杀手不太冷
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2913554676.jpg
# 8 星际穿越
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2614988097.jpg
# 9 盗梦空间
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p513344864.jpg
# 10 楚门的世界
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p479682972.jpg
# 11 辛德勒的名单
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p492406163.jpg
# 12 忠犬八公的故事
# ...

# %%
movielis=[]
for i in range(10):
    url='https://movie.douban.com/top250?start='+str(i*25)+'&filter='
    movielis.append(url)

# %%
movielis
# Out:
# ['https://movie.douban.com/top250?start=0&filter=',
#  'https://movie.douban.com/top250?start=25&filter=',
#  'https://movie.douban.com/top250?start=50&filter=',
#  'https://movie.douban.com/top250?start=75&filter=',
#  'https://movie.douban.com/top250?start=100&filter=',
#  'https://movie.douban.com/top250?start=125&filter=',
#  'https://movie.douban.com/top250?start=150&filter=',
#  'https://movie.douban.com/top250?start=175&filter=',
#  'https://movie.douban.com/top250?start=200&filter=',
#  'https://movie.douban.com/top250?start=225&filter=']

# %%
import requests
import re
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}

movielis=[]
for i in range(10):
    url='https://movie.douban.com/top250?start='+str(i*25)+'&filter='
    movielis.append(url)
    
for url in movielis:
    res = requests.get(url, headers=headers).text 
    p_title='<a href=".*?">\n                            <span class="title">(.*?)</span>'
    title=re.findall(p_title,res)
    p_img='<img width="100" alt=".*?" src="(.*?)">'
    img=re.findall(p_img,res)

    for i in range(25):
        print(str(i+1)+' '+title[i])
        print(img[i])
#        res1 = requests.get(img[i])
#        file = open('C:/Users/Administrator/Desktop/movies/'+title[i]+'.jpg', 'wb')  # 注意要以二进制的方式写入
#        file.write(res1.content)
#        file.close()
# Out:
# 1 肖申克的救赎
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg
# 2 霸王别姬
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg
# 3 泰坦尼克号
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg
# 4 阿甘正传
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg
# 5 千与千寻
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2557573348.jpg
# 6 美丽人生
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2578474613.jpg
# 7 这个杀手不太冷
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2913554676.jpg
# 8 星际穿越
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2614988097.jpg
# 9 盗梦空间
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p513344864.jpg
# 10 楚门的世界
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p479682972.jpg
# 11 辛德勒的名单
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p492406163.jpg
# 12 忠犬八公的故事
# ...

# %%
import requests
import re
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'}

movielis=[]
for i in range(10):
    url='https://movie.douban.com/top250?start='+str(i*25)+'&filter='
    movielis.append(url)
    
for j in range(10):
    url=movielis[j]
    res = requests.get(url, headers=headers).text 
    p_title='<a href=".*?">\n                            <span class="title">(.*?)</span>'
    title=re.findall(p_title,res)
    p_img='<img width="100" alt=".*?" src="(.*?)">'
    img=re.findall(p_img,res)

    for i in range(25):
        print(str(i+1+j*25)+' '+title[i])
        print(img[i])
# Out:
# 1 肖申克的救赎
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p480747492.jpg
# 2 霸王别姬
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2561716440.jpg
# 3 泰坦尼克号
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p457760035.jpg
# 4 阿甘正传
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2372307693.jpg
# 5 千与千寻
# https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2557573348.jpg
# 6 美丽人生
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2578474613.jpg
# 7 这个杀手不太冷
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2913554676.jpg
# 8 星际穿越
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2614988097.jpg
# 9 盗梦空间
# https://img9.doubanio.com/view/photo/s_ratio_poster/public/p513344864.jpg
# 10 楚门的世界
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p479682972.jpg
# 11 辛德勒的名单
# https://img3.doubanio.com/view/photo/s_ratio_poster/public/p492406163.jpg
# 12 忠犬八公的故事
# ...
